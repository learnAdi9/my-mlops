# %% [markdown]
# # Start

# %%
from IPython import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# %cd drive/My Drive/Works/X-ops/ml-ops/zCamp
# !python --version
# Out:
# '/content'
# /content/drive/My Drive/Works/X-ops/ml-ops/zCamp
# Python 3.10.12

# %% [markdown]
# # 💻 Installation - Environment

# %%
# importing required packages $
import pandas as pd

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression

# from sklearn.metrics import mean_squared_error

# %% [markdown]
# # EDA to Homework-1!!

# %% [markdown]
# * [Data Source - Yello Taxi](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page)

# %% [markdown]
# ## IN MAZE !!

# %%
# Ingesting data check IN mage - Pipe1!

df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet')
len(df)
# Out:
# 3403766

# %%
# Preparing data function - Pipe2!

def prep_data(data_source):
  df = pd.read_parquet(data_source)
  # Creating duration variable & examining it !
  df['duration'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']
  df['duration'] = df['duration'].apply(lambda dur: round(dur.total_seconds() / 60 , 2))
  df = df[(df.duration >= 1) & (df.duration <= 60)]
  # cat-features from EDA
  cat_features = ['PULocationID', 'DOLocationID']
  df[cat_features] = df[cat_features].astype(str)

  return df

# %%
# Preparing Data using Mar-2023 data (Yellow Taxi)!
df = prep_data(data_source = 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet')
len(df)
# Out:
# <ipython-input-6-d5366acc39f0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_features] = df[cat_features].astype(str)
# 3316216

# %%
# Use prep_data to return DictVect & trained Model - Pipe3!

def vect_and_train(df):
  # Dictionary Vectorizer & X_train data
  dVec = DictVectorizer()
  feature_dicts = df[['PULocationID', 'DOLocationID']].to_dict(orient = 'records')
  X_train = dVec.fit_transform(feature_dicts)
  # Obtaining target and creating target vector !
  y_train = df['duration'].values.copy()

  # Training a Simple Linear Reg Model !
  lr = LinearRegression()
  model = lr.fit(X_train, y_train)
  print("Intercept: ",model.intercept_)

  return dVec, model

# %%
# Call and Check
_ = vect_and_train(df)
# Out:
# Intercept:  24.776404219962643

# %%
# Training RMSE: Q5 - Ans !
# y_pred = model.predict(X_train)
# mean_squared_error(y_train, y_pred, squared = False)
